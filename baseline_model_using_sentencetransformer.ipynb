# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/AIBootCamp/NLP/
# Out:
# /content/drive/MyDrive/AIBootCamp/NLP

# %%
! pip install sentence_transformers datasets

# %% [markdown]
# # SET

# %%
import math
import logging
from datetime import datetime

import torch
from torch.utils.data import DataLoader
from datasets import load_dataset
from sentence_transformers import SentenceTransformer, models, LoggingHandler, losses, util
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sentence_transformers.readers import InputExample

# %%
#logger
logging.basicConfig(format="%(asctime)s - %(message)s",
                    datefmt="%Y/%m/%d %H:%M",
                    level=logging.INFO,
                    handlers=[LoggingHandler()]
                    )

# %%
pretrained_model = 'klue/roberta-base'
sts_num_epochs = 3
train_batch_size = 32

sts_model_save_path = 'output/train_sts_'+pretrained_model.replace('/','_') + datetime.now().strftime("%m/%d %H:%M:%S")

# %% [markdown]
# # DataLoad

# %%
# load KLUE-STS Dataset
klue_sts_train = load_dataset("klue", "sts", split='train[:90%]')
klue_sts_valid = load_dataset("klue", "sts", split='train[-10%:]') # train의 10%를 validation set으로 사용
klue_sts_test = load_dataset("klue", "sts", split='validation')

print('Length of Train : ',len(klue_sts_train))
print('Length of Valid : ',len(klue_sts_valid))
print('Length of Test : ',len(klue_sts_test))
# Out:
# Downloading builder script:   0%|          | 0.00/5.21k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.93k [00:00<?, ?B/s]
# Downloading and preparing dataset klue/sts (download: 1.29 MiB, generated: 2.82 MiB, post-processed: Unknown size, total: 4.11 MiB) to /root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e...
# Downloading data:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/11668 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/519 [00:00<?, ? examples/s]
# Dataset klue downloaded and prepared to /root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e. Subsequent calls will reuse this data.
# 2022-05-25 05:47:36,898 - Reusing dataset klue (/root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e)
# 2022-05-25 05:47:37,351 - Reusing dataset klue (/root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e)
# Length of Train :  10501
# Length of Valid :  1167
# Length of Test :  519

# %% [markdown]
# label >= 3 : 1 </br>
# lable < 3 : 0

# %%
def make_input_ex_sts(dataset):
  '''
  transform to the Input example
  '''
  input_examples = []
  for i, data in enumerate(dataset):
    sentence1 = data['sentence1']
    sentence2 = data['sentence2']
    score = (data['labels']['label']) / 5.0 # normalize 0 to 1
    input_examples.append(InputExample(texts=[sentence1, sentence2], label=score))
  
  return input_examples

# %%
sts_train_examples = make_input_ex_sts(klue_sts_train)
sts_valid_examples = make_input_ex_sts(klue_sts_valid)
sts_test_examples = make_input_ex_sts(klue_sts_test)

# %%
train_dataloader = DataLoader(sts_train_examples,
                             shuffle=True,
                             batch_size=train_batch_size)

#evaluator by valid
dev_evaluator = EmbeddingSimilarityEvaluator.from_input_examples(
    sts_valid_examples,
    name='sts-dev'
)

# %% [markdown]
# # Load Embedding Model

# %%
# Load baseline model

base_model = models.Transformer(model_name_or_path=pretrained_model,
                                max_seq_length=256,
                                do_lower_case=True)

# Only use Mean Pooling -> Pooling all token embedding vectors of sentence.
pooling_model = models.Pooling(
    base_model.get_word_embedding_dimension(),
    pooling_mode_mean_tokens=True,
    pooling_mode_cls_token=False,
    pooling_mode_max_tokens=False,
)

model = SentenceTransformer(modules=[base_model,pooling_model])
# Out:
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2022-05-25 06:45:30,191 - Use pytorch device: cpu

# %%
# Use MultipleNegativesRankingLoss
train_loss = losses.MultipleNegativesRankingLoss(model)

# warmup steps
warmup_steps = math.ceil(len(sts_train_examples) * sts_num_epochs / train_batch_size * 0.1) #10% of train data for warm-up
logging.info("Warmup-steps: {}".format(warmup_steps))

# Training
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    evaluator=dev_evaluator,
    epochs=sts_num_epochs,
    evaluation_steps=int(len(train_dataloader)*0.1),
    warmup_steps=warmup_steps,
    output_path=sts_model_save_path,
    use_amp=False       #Set to True, if your GPU supports FP16 operations
)
# Out:
# 2022-05-25 06:45:40,239 - Warmup-steps: 99
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/329 [00:00<?, ?it/s]
# 2022-05-25 07:01:09,768 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 32 steps:
# 2022-05-25 07:04:11,537 - Cosine-Similarity :	Pearson: 0.8996	Spearman: 0.8997
# 2022-05-25 07:04:11,543 - Manhattan-Distance:	Pearson: 0.8938	Spearman: 0.8929
# 2022-05-25 07:04:11,545 - Euclidean-Distance:	Pearson: 0.8919	Spearman: 0.8917
# 2022-05-25 07:04:11,546 - Dot-Product-Similarity:	Pearson: 0.8357	Spearman: 0.8323
# 2022-05-25 07:04:11,577 - Save model to output/train_sts_klue_roberta-base05/25 06:41:29
# 2022-05-25 07:19:17,268 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 64 steps:
# 2022-05-25 07:22:13,050 - Cosine-Similarity :	Pearson: 0.8806	Spearman: 0.8830
# 2022-05-25 07:22:13,052 - Manhattan-Distance:	Pearson: 0.8606	Spearman: 0.8705
# 2022-05-25 07:22:13,052 - Euclidean-Distance:	Pearson: 0.8599	Spearman: 0.8700
# 2022-05-25 07:22:13,053 - Dot-Product-Similarity:	Pearson: 0.7605	Spearman: 0.7673
# 2022-05-25 07:37:00,243 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 96 steps:
# 2022-05-25 07:39:57,598 - Cosine-Similarity :	Pearson: 0.8715	Spearman: 0.8756
# 2022-05-25 07:39:57,600 - Manhattan-Distance:	Pearson: 0.8587	Spearman: 0.8708
# 2022-05-25 07:39:57,600 - Euclidean-Distance:	Pearson: 0.8590	Spearman: 0.8715
# 2022-05-25 07:39:57,600 - Dot-Product-Similarity:	Pearson: 0.6065	Spearman: 0.6016
# 2022-05-25 07:54:09,280 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 128 steps:
# 2022-05-25 07:57:21,618 - Cosine-Similarity :	Pearson: 0.8351	Spearman: 0.8409
# 2022-05-25 07:57:21,621 - Manhattan-Distance:	Pearson: 0.8608	Spearman: 0.8740
# 2022-05-25 07:57:21,622 - Euclidean-Distance:	Pearson: 0.8606	Spearman: 0.8739
# 2022-05-25 07:57:21,622 - Dot-Product-Similarity:	Pearson: 0.4723	Spearman: 0.4745
# 2022-05-25 08:11:55,563 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 160 steps:
# 2022-05-25 08:14:44,086 - Cosine-Similarity :	Pearson: 0.7922	Spearman: 0.7966
# 2022-05-25 08:14:44,088 - Manhattan-Distance:	Pearson: 0.8558	Spearman: 0.8621
# 2022-05-25 08:14:44,089 - Euclidean-Distance:	Pearson: 0.8560	Spearman: 0.8625
# 2022-05-25 08:14:44,089 - Dot-Product-Similarity:	Pearson: 0.3715	Spearman: 0.3517
# 2022-05-25 08:28:47,281 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 192 steps:
# 2022-05-25 08:31:39,558 - Cosine-Similarity :	Pearson: 0.8284	Spearman: 0.8321
# 2022-05-25 08:31:39,562 - Manhattan-Distance:	Pearson: 0.8597	Spearman: 0.8684
# 2022-05-25 08:31:39,564 - Euclidean-Distance:	Pearson: 0.8598	Spearman: 0.8690
# 2022-05-25 08:31:39,565 - Dot-Product-Similarity:	Pearson: 0.4673	Spearman: 0.4472
# 2022-05-25 08:45:18,365 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 224 steps:
# 2022-05-25 08:48:12,465 - Cosine-Similarity :	Pearson: 0.7850	Spearman: 0.7847
# 2022-05-25 08:48:12,469 - Manhattan-Distance:	Pearson: 0.8569	Spearman: 0.8604
# 2022-05-25 08:48:12,470 - Euclidean-Distance:	Pearson: 0.8573	Spearman: 0.8610
# 2022-05-25 08:48:12,471 - Dot-Product-Similarity:	Pearson: 0.3612	Spearman: 0.3321
# 2022-05-25 09:01:56,771 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 256 steps:
# 2022-05-25 09:04:48,641 - Cosine-Similarity :	Pearson: 0.7717	Spearman: 0.7649
# 2022-05-25 09:04:48,643 - Manhattan-Distance:	Pearson: 0.8543	Spearman: 0.8515
# 2022-05-25 09:04:48,643 - Euclidean-Distance:	Pearson: 0.8547	Spearman: 0.8519
# 2022-05-25 09:04:48,643 - Dot-Product-Similarity:	Pearson: 0.3352	Spearman: 0.3134
# 2022-05-25 09:19:55,939 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 288 steps:
# 2022-05-25 09:22:47,545 - Cosine-Similarity :	Pearson: 0.7938	Spearman: 0.7890
# 2022-05-25 09:22:47,549 - Manhattan-Distance:	Pearson: 0.8512	Spearman: 0.8558
# 2022-05-25 09:22:47,550 - Euclidean-Distance:	Pearson: 0.8516	Spearman: 0.8564
# 2022-05-25 09:22:47,551 - Dot-Product-Similarity:	Pearson: 0.3617	Spearman: 0.3405
# 2022-05-25 09:37:31,836 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 320 steps:
# 2022-05-25 09:40:27,400 - Cosine-Similarity :	Pearson: 0.7678	Spearman: 0.7648
# 2022-05-25 09:40:27,403 - Manhattan-Distance:	Pearson: 0.8406	Spearman: 0.8456
# 2022-05-25 09:40:27,403 - Euclidean-Distance:	Pearson: 0.8410	Spearman: 0.8460
# 2022-05-25 09:40:27,403 - Dot-Product-Similarity:	Pearson: 0.3357	Spearman: 0.3240
# 2022-05-25 09:44:20,954 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-05-25 09:47:19,720 - Cosine-Similarity :	Pearson: 0.7512	Spearman: 0.7463
# 2022-05-25 09:47:19,722 - Manhattan-Distance:	Pearson: 0.8272	Spearman: 0.8307
# 2022-05-25 09:47:19,724 - Euclidean-Distance:	Pearson: 0.8278	Spearman: 0.8313
# 2022-05-25 09:47:19,725 - Dot-Product-Similarity:	Pearson: 0.3094	Spearman: 0.2928
# Iteration:   0%|          | 0/329 [00:00<?, ?it/s]
# 2022-05-25 10:02:08,601 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 32 steps:
# 2022-05-25 10:05:06,743 - Cosine-Similarity :	Pearson: 0.7545	Spearman: 0.7505
# 2022-05-25 10:05:06,745 - Manhattan-Distance:	Pearson: 0.8449	Spearman: 0.8455
# 2022-05-25 10:05:06,745 - Euclidean-Distance:	Pearson: 0.8452	Spearman: 0.8459
# 2022-05-25 10:05:06,746 - Dot-Product-Similarity:	Pearson: 0.3480	Spearman: 0.3356
# 2022-05-25 10:20:06,746 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 64 steps:
# 2022-05-25 10:23:06,130 - Cosine-Similarity :	Pearson: 0.7787	Spearman: 0.7691
# 2022-05-25 10:23:06,133 - Manhattan-Distance:	Pearson: 0.8434	Spearman: 0.8431
# 2022-05-25 10:23:06,134 - Euclidean-Distance:	Pearson: 0.8435	Spearman: 0.8431
# 2022-05-25 10:23:06,134 - Dot-Product-Similarity:	Pearson: 0.3903	Spearman: 0.3614
# 2022-05-25 10:37:26,429 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 96 steps:
# 2022-05-25 10:40:27,751 - Cosine-Similarity :	Pearson: 0.7803	Spearman: 0.7777
# 2022-05-25 10:40:27,753 - Manhattan-Distance:	Pearson: 0.8499	Spearman: 0.8521
# 2022-05-25 10:40:27,754 - Euclidean-Distance:	Pearson: 0.8499	Spearman: 0.8522
# 2022-05-25 10:40:27,754 - Dot-Product-Similarity:	Pearson: 0.4098	Spearman: 0.3908
# 2022-05-25 10:55:15,720 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 128 steps:
# 2022-05-25 10:58:14,827 - Cosine-Similarity :	Pearson: 0.7746	Spearman: 0.7709
# 2022-05-25 10:58:14,829 - Manhattan-Distance:	Pearson: 0.8505	Spearman: 0.8533
# 2022-05-25 10:58:14,829 - Euclidean-Distance:	Pearson: 0.8507	Spearman: 0.8533
# 2022-05-25 10:58:14,830 - Dot-Product-Similarity:	Pearson: 0.4065	Spearman: 0.3832
# 2022-05-25 11:13:25,784 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 160 steps:
# 2022-05-25 11:16:22,173 - Cosine-Similarity :	Pearson: 0.7932	Spearman: 0.7913
# 2022-05-25 11:16:22,178 - Manhattan-Distance:	Pearson: 0.8470	Spearman: 0.8517
# 2022-05-25 11:16:22,179 - Euclidean-Distance:	Pearson: 0.8474	Spearman: 0.8521
# 2022-05-25 11:16:22,180 - Dot-Product-Similarity:	Pearson: 0.4430	Spearman: 0.4118
# 2022-05-25 11:30:59,134 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 192 steps:
# 2022-05-25 11:34:03,081 - Cosine-Similarity :	Pearson: 0.7495	Spearman: 0.7391
# 2022-05-25 11:34:03,085 - Manhattan-Distance:	Pearson: 0.8333	Spearman: 0.8353
# 2022-05-25 11:34:03,086 - Euclidean-Distance:	Pearson: 0.8335	Spearman: 0.8355
# 2022-05-25 11:34:03,087 - Dot-Product-Similarity:	Pearson: 0.3467	Spearman: 0.3225
# 2022-05-25 11:48:18,745 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 224 steps:
# 2022-05-25 11:51:17,135 - Cosine-Similarity :	Pearson: 0.7485	Spearman: 0.7423
# 2022-05-25 11:51:17,140 - Manhattan-Distance:	Pearson: 0.8387	Spearman: 0.8418
# 2022-05-25 11:51:17,141 - Euclidean-Distance:	Pearson: 0.8382	Spearman: 0.8409
# 2022-05-25 11:51:17,142 - Dot-Product-Similarity:	Pearson: 0.3527	Spearman: 0.3294
# 2022-05-25 12:05:24,963 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 256 steps:
# 2022-05-25 12:08:37,194 - Cosine-Similarity :	Pearson: 0.7664	Spearman: 0.7572
# 2022-05-25 12:08:37,196 - Manhattan-Distance:	Pearson: 0.8398	Spearman: 0.8429
# 2022-05-25 12:08:37,196 - Euclidean-Distance:	Pearson: 0.8392	Spearman: 0.8421
# 2022-05-25 12:08:37,197 - Dot-Product-Similarity:	Pearson: 0.3786	Spearman: 0.3500
# 2022-05-25 12:23:18,068 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 288 steps:
# 2022-05-25 12:26:15,094 - Cosine-Similarity :	Pearson: 0.7597	Spearman: 0.7489
# 2022-05-25 12:26:15,098 - Manhattan-Distance:	Pearson: 0.8536	Spearman: 0.8516
# 2022-05-25 12:26:15,100 - Euclidean-Distance:	Pearson: 0.8533	Spearman: 0.8512
# 2022-05-25 12:26:15,101 - Dot-Product-Similarity:	Pearson: 0.3504	Spearman: 0.3282
# 2022-05-25 12:40:34,847 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 320 steps:
# 2022-05-25 12:43:35,640 - Cosine-Similarity :	Pearson: 0.7410	Spearman: 0.7303
# 2022-05-25 12:43:35,646 - Manhattan-Distance:	Pearson: 0.8455	Spearman: 0.8433
# 2022-05-25 12:43:35,647 - Euclidean-Distance:	Pearson: 0.8452	Spearman: 0.8428
# 2022-05-25 12:43:35,647 - Dot-Product-Similarity:	Pearson: 0.3134	Spearman: 0.3072
# 2022-05-25 12:47:33,867 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-05-25 12:50:34,509 - Cosine-Similarity :	Pearson: 0.7485	Spearman: 0.7369
# 2022-05-25 12:50:34,511 - Manhattan-Distance:	Pearson: 0.8556	Spearman: 0.8505
# 2022-05-25 12:50:34,513 - Euclidean-Distance:	Pearson: 0.8555	Spearman: 0.8501
# 2022-05-25 12:50:34,514 - Dot-Product-Similarity:	Pearson: 0.3204	Spearman: 0.3140
# Iteration:   0%|          | 0/329 [00:00<?, ?it/s]
# 2022-05-25 13:04:46,812 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 32 steps:
# 2022-05-25 13:07:46,952 - Cosine-Similarity :	Pearson: 0.7633	Spearman: 0.7536
# 2022-05-25 13:07:46,958 - Manhattan-Distance:	Pearson: 0.8483	Spearman: 0.8492
# 2022-05-25 13:07:46,959 - Euclidean-Distance:	Pearson: 0.8481	Spearman: 0.8486
# 2022-05-25 13:07:46,960 - Dot-Product-Similarity:	Pearson: 0.3551	Spearman: 0.3337
# 2022-05-25 13:22:18,711 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 64 steps:
# 2022-05-25 13:25:36,223 - Cosine-Similarity :	Pearson: 0.7640	Spearman: 0.7512
# 2022-05-25 13:25:36,227 - Manhattan-Distance:	Pearson: 0.8524	Spearman: 0.8496
# 2022-05-25 13:25:36,228 - Euclidean-Distance:	Pearson: 0.8521	Spearman: 0.8490
# 2022-05-25 13:25:36,228 - Dot-Product-Similarity:	Pearson: 0.3614	Spearman: 0.3372
# 2022-05-25 13:41:01,009 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 96 steps:
# 2022-05-25 13:44:00,883 - Cosine-Similarity :	Pearson: 0.7617	Spearman: 0.7490
# 2022-05-25 13:44:00,886 - Manhattan-Distance:	Pearson: 0.8486	Spearman: 0.8478
# 2022-05-25 13:44:00,887 - Euclidean-Distance:	Pearson: 0.8482	Spearman: 0.8474
# 2022-05-25 13:44:00,887 - Dot-Product-Similarity:	Pearson: 0.3577	Spearman: 0.3334
# 2022-05-25 13:59:07,511 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 128 steps:
# 2022-05-25 14:02:16,595 - Cosine-Similarity :	Pearson: 0.7738	Spearman: 0.7613
# 2022-05-25 14:02:16,599 - Manhattan-Distance:	Pearson: 0.8494	Spearman: 0.8501
# 2022-05-25 14:02:16,600 - Euclidean-Distance:	Pearson: 0.8490	Spearman: 0.8496
# 2022-05-25 14:02:16,602 - Dot-Product-Similarity:	Pearson: 0.3833	Spearman: 0.3577
# 2022-05-25 14:17:17,455 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 160 steps:
# 2022-05-25 14:20:27,317 - Cosine-Similarity :	Pearson: 0.7693	Spearman: 0.7567
# 2022-05-25 14:20:27,319 - Manhattan-Distance:	Pearson: 0.8508	Spearman: 0.8504
# 2022-05-25 14:20:27,320 - Euclidean-Distance:	Pearson: 0.8506	Spearman: 0.8503
# 2022-05-25 14:20:27,320 - Dot-Product-Similarity:	Pearson: 0.3717	Spearman: 0.3483
# 2022-05-25 14:35:14,995 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 192 steps:
# 2022-05-25 14:38:19,844 - Cosine-Similarity :	Pearson: 0.7541	Spearman: 0.7408
# 2022-05-25 14:38:19,846 - Manhattan-Distance:	Pearson: 0.8463	Spearman: 0.8466
# 2022-05-25 14:38:19,846 - Euclidean-Distance:	Pearson: 0.8459	Spearman: 0.8461
# 2022-05-25 14:38:19,847 - Dot-Product-Similarity:	Pearson: 0.3475	Spearman: 0.3314
# 2022-05-25 14:53:23,667 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 224 steps:
# 2022-05-25 14:56:31,755 - Cosine-Similarity :	Pearson: 0.7651	Spearman: 0.7523
# 2022-05-25 14:56:31,758 - Manhattan-Distance:	Pearson: 0.8517	Spearman: 0.8518
# 2022-05-25 14:56:31,759 - Euclidean-Distance:	Pearson: 0.8514	Spearman: 0.8514
# 2022-05-25 14:56:31,759 - Dot-Product-Similarity:	Pearson: 0.3623	Spearman: 0.3411
# 2022-05-25 15:11:39,194 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 256 steps:
# 2022-05-25 15:14:40,838 - Cosine-Similarity :	Pearson: 0.7660	Spearman: 0.7527
# 2022-05-25 15:14:40,842 - Manhattan-Distance:	Pearson: 0.8530	Spearman: 0.8524
# 2022-05-25 15:14:40,842 - Euclidean-Distance:	Pearson: 0.8527	Spearman: 0.8523
# 2022-05-25 15:14:40,843 - Dot-Product-Similarity:	Pearson: 0.3668	Spearman: 0.3477
# 2022-05-25 15:30:07,214 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 288 steps:
# 2022-05-25 15:33:10,666 - Cosine-Similarity :	Pearson: 0.7637	Spearman: 0.7518
# 2022-05-25 15:33:10,670 - Manhattan-Distance:	Pearson: 0.8477	Spearman: 0.8490
# 2022-05-25 15:33:10,670 - Euclidean-Distance:	Pearson: 0.8474	Spearman: 0.8488
# 2022-05-25 15:33:10,671 - Dot-Product-Similarity:	Pearson: 0.3654	Spearman: 0.3456
# 2022-05-25 15:48:20,030 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 320 steps:
# 2022-05-25 15:51:24,115 - Cosine-Similarity :	Pearson: 0.7648	Spearman: 0.7531
# 2022-05-25 15:51:24,118 - Manhattan-Distance:	Pearson: 0.8478	Spearman: 0.8491
# 2022-05-25 15:51:24,118 - Euclidean-Distance:	Pearson: 0.8476	Spearman: 0.8490
# 2022-05-25 15:51:24,118 - Dot-Product-Similarity:	Pearson: 0.3678	Spearman: 0.3474
# 2022-05-25 15:55:17,169 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-05-25 15:58:17,849 - Cosine-Similarity :	Pearson: 0.7648	Spearman: 0.7531
# 2022-05-25 15:58:17,852 - Manhattan-Distance:	Pearson: 0.8479	Spearman: 0.8492
# 2022-05-25 15:58:17,853 - Euclidean-Distance:	Pearson: 0.8477	Spearman: 0.8490
# 2022-05-25 15:58:17,853 - Dot-Product-Similarity:	Pearson: 0.3679	Spearman: 0.3475

# %%
# Evaluator by sts-test
test_evaluator = EmbeddingSimilarityEvaluator.from_input_examples(
    sts_test_examples,
    name="sts-test",
)

# %%
# evaluation sts-test
test_evaluator(model, output_path=sts_model_save_path)
# Out:
# 2022-05-25 16:03:00,175 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-test dataset:
# 2022-05-25 16:04:23,081 - Cosine-Similarity :	Pearson: 0.3397	Spearman: 0.3409
# 2022-05-25 16:04:23,083 - Manhattan-Distance:	Pearson: 0.4193	Spearman: 0.3919
# 2022-05-25 16:04:23,084 - Euclidean-Distance:	Pearson: 0.4179	Spearman: 0.3896
# 2022-05-25 16:04:23,084 - Dot-Product-Similarity:	Pearson: 0.1782	Spearman: 0.1695
# 0.39185234414549436
